# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_style("darkgrid")
# %matplotlib inline

# %%
data = pd.read_csv("../data/deu.train", header=None, names=["Token", "Lemma", "POS", "Chunk", "Label"], delimiter=' ')
data.head()
# Out:
#         Token      Lemma  POS Chunk Label
# 0  -DOCSTART-        -X-  -X-   -X-     O
# 1    Ereignis   Ereignis   NN  B-NC     O
# 2         und        und  KON     O     O
# 3   Erzählung  Erzählung   NN  B-NC     O
# 4        oder       oder  KON  I-NC     O

# %%
data= data.dropna()

# %%
data["TokenLen"] = data["Token"].apply(len)
data= data[1:]

# %%
data["Coarse-label"] = data["Label"].apply(lambda x: x.split("-")[-1])
data.head()
# Out:
#        Token      Lemma  POS Chunk Label  TokenLen Coarse-label
# 1   Ereignis   Ereignis   NN  B-NC     O         8            O
# 2        und        und  KON     O     O         3            O
# 3  Erzählung  Erzählung   NN  B-NC     O         9            O
# 4       oder       oder  KON  I-NC     O         4            O
# 5          :          :   $.     O     O         1            O

# %%
grouped_data = data.groupby("Coarse-label")

# %%
list(set(data["Coarse-label"]))
# Out:
# ['O', 'LOC', 'MISC', 'PER', 'ORG']

# %%
my_palette = sns.color_palette("muted")
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})
# fig, axes = plt.subplots(1, 5, figsize=(10, 3), sharey=True, dpi = 200)
i,j = 0,0
for group in list(set(data["Coarse-label"])):
    print("Basic Stats for group for {0}".format(group))
    subset = grouped_data.get_group(group)
    print("Mode of Token Length", stats.mode(subset["TokenLen"]))
    print("Mean of the Token Length", np.mean(subset["TokenLen"]))
    print("Max: {0} and min: {1} ".format(max(subset["TokenLen"]), min(subset["TokenLen"])))
    print(i, j)
    sns.distplot(subset["TokenLen"], hist=False, kde=True,label = group)
    plt.legend()
    plt.xlim(0,20)
#     sns.boxplot(subset["TokenLen"], ax=axes[i,j])
#     i += 1
#     if(j == 3):
#         j = 0
#         i += 1
# Out:
# Basic Stats for group for O
# Mode of Token Length ModeResult(mode=array([3]), count=array([45684]))
# Mean of the Token Length 5.132090783671924
# Max: 38 and min: 1
# 0 0
# Basic Stats for group for LOC
# Mode of Token Length ModeResult(mode=array([9]), count=array([710]))
# Mean of the Token Length 9.236203933549742
# Max: 34 and min: 1
# 0 0
# Basic Stats for group for MISC
# Mode of Token Length ModeResult(mode=array([11]), count=array([352]))
# Mean of the Token Length 10.2326327039544
# Max: 34 and min: 1
# 0 0
# Basic Stats for group for PER
# Mode of Token Length ModeResult(mode=array([6]), count=array([1001]))
# Mean of the Token Length 6.49098998887653
# Max: 20 and min: 1
# 0 0
# Basic Stats for group for ORG
# Mode of Token Length ModeResult(mode=array([3]), count=array([863]))
# Mean of the Token Length 7.36681635547152
# Max: 34 and min: 1
# 0 0

# %%
data = pd.read_csv("../data/deu.train", 
                   header=None, 
                   names=["Token", "Lemma", "POS", "Chunk", "Label"], 
                   delimiter=' ', skip_blank_lines = False)

data['EOS'] = pd.isnull(data["Token"])
data.head()
# Out:
#         Token      Lemma  POS Chunk Label    EOS
# 0  -DOCSTART-        -X-  -X-   -X-     O  False
# 1         NaN        NaN  NaN   NaN   NaN   True
# 2    Ereignis   Ereignis   NN  B-NC     O  False
# 3         und        und  KON     O     O  False
# 4   Erzählung  Erzählung   NN  B-NC     O  False

# %%
import math
from tqdm import tqdm

position_in_sen = []
temp = 0
for row in tqdm(range(0,len(data))):
#     print(data.iloc[row])
    position_in_sen.append(temp)
    if data.iloc[row]["EOS"] == True:
        temp = 0
    else:
        temp = temp+1
# Out:
# 100%|██████████| 220189/220189 [00:36<00:00, 5989.17it/s]

# %%
data["position"] = position_in_sen
data.head()
# Out:
#         Token      Lemma  POS Chunk Label    EOS  position
# 0  -DOCSTART-        -X-  -X-   -X-     O  False         0
# 1         NaN        NaN  NaN   NaN   NaN   True         1
# 2    Ereignis   Ereignis   NN  B-NC     O  False         0
# 3         und        und  KON     O     O  False         1
# 4   Erzählung  Erzählung   NN  B-NC     O  False         2

# %%
data = data.dropna(subset=["Label", "Token"])

# %%
data["Coarse-label"] = data["Label"].apply(lambda x: x.split("-")[-1])
data.head()
# Out:
#         Token      Lemma  POS Chunk Label    EOS  position Coarse-label
# 0  -DOCSTART-        -X-  -X-   -X-     O  False         0            O
# 2    Ereignis   Ereignis   NN  B-NC     O  False         0            O
# 3         und        und  KON     O     O  False         1            O
# 4   Erzählung  Erzählung   NN  B-NC     O  False         2            O
# 5        oder       oder  KON  I-NC     O  False         3            O

# %%
grouped_data = data.groupby("Coarse-label")

# %%
for group in list(set(data["Coarse-label"])):
    print("Basic Stats for group for {0}".format(group))
    subset = grouped_data.get_group(group)
    print("Mode of Position in a sentence ", stats.mode(subset["position"]))
    print("Mean of the Position in a sentence ", np.mean(subset["position"]))
    print("Max: {0} and min: {1} ".format(max(subset["position"]), min(subset["position"])))
    print(i, j)
    sns.distplot(subset["position"], hist=False, kde=True,label = group)
    plt.legend()
# Out:
# Basic Stats for group for O
# Mode of Position in a sentence  ModeResult(mode=array([0]), count=array([11103]))
# Mean of the Position in a sentence  11.236950594040122
# Max: 100 and min: 0
# 0 0
# Basic Stats for group for LOC
# Mode of Position in a sentence  ModeResult(mode=array([0]), count=array([501]))
# Mean of the Position in a sentence  11.700973839984725
# Max: 65 and min: 0
# 0 0
# Basic Stats for group for MISC
# Mode of Position in a sentence  ModeResult(mode=array([1]), count=array([177]))
# Mean of the Position in a sentence  11.86676166726042
# Max: 90 and min: 0
# 0 0
# Basic Stats for group for PER
# Mode of Position in a sentence  ModeResult(mode=array([1]), count=array([434]))
# Mean of the Position in a sentence  9.731924360400445
# Max: 64 and min: 0
# 0 0
# Basic Stats for group for ORG
# Mode of Position in a sentence  ModeResult(mode=array([4]), count=array([262]))
# Mean of the Position in a sentence  12.292602221696999
# Max: 93 and min: 0
# 0 0

# %%
grouped_data = data.groupby("Label")

# %%
for group in list(set(data["Label"])):
    print("Basic Stats for group for {0}".format(group))
    subset = grouped_data.get_group(group)
    print("Mode of Position in a sentence ", stats.mode(subset["position"]))
    print("Mean of the Position in a sentence ", np.mean(subset["position"]))
    print("Max: {0} and min: {1} ".format(max(subset["position"]), min(subset["position"])))
    print(i, j)
    sns.distplot(subset["position"], hist=False, kde=True,label = group)
#     plt.xlim(0,20)    
    plt.legend()
# Out:
# Basic Stats for group for O
# Mode of Position in a sentence  ModeResult(mode=array([0]), count=array([11103]))
# Mean of the Position in a sentence  11.236950594040122
# Max: 100 and min: 0
# 0 0
# Basic Stats for group for B-MISC
# Mode of Position in a sentence  ModeResult(mode=array([1]), count=array([154]))
# Mean of the Position in a sentence  11.49256993006993
# Max: 89 and min: 0
# 0 0
# Basic Stats for group for I-MISC
# Mode of Position in a sentence  ModeResult(mode=array([3]), count=array([32]))
# Mean of the Position in a sentence  13.516377649325626
# Max: 90 and min: 1
# 0 0
# Basic Stats for group for I-LOC
# Mode of Position in a sentence  ModeResult(mode=array([1]), count=array([84]))
# Mean of the Position in a sentence  13.24
# Max: 52 and min: 1
# 0 0
# Basic Stats for group for B-ORG
# Mode of Position in a sentence  ModeResult(mode=array([1]), count=array([157]))
# Mean of the Position in a sentence  11.612211221122113
# Max: 92 and min: 0
# 0 0
# Basic Stats for group for I-PER
# Mode of Position in a sentence  ModeResult(mode=array([1]), count=array([234]))
# Mean of the Position in a sentence  10.541811846689896
# Max: 63 and min: 1
# 0 0
# Basic Stats for group for B-LOC
# Mode of Position in a sentence  ModeResult(mode=array([0]), count=array([501]))
# Mean of the Position in a sentence  11.3922512608895
# Max: 65 and min: 0
# 0 0
# Basic Stats for group for I-ORG
# Mode of Position in a sentence  ModeResult(mode=array([2]), count=array([137]))
# Mean of the Position in a sentence  13.205312672938572
# Max: 93 and min: 1
# 0 0
# Basic Stats for group for B-PER
# Mode of Position in a sentence  ModeResult(mode=array([0]), count=array([429]))
# Mean of the Position in a sentence  9.228993869455463
# Max: 64 and min: 0
# 0 0

# %%
grouped_data = data.groupby(["Coarse-label", "POS"])

# %%
import scipy.stats as ss

def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
def cramers_corrected_stat(confusion_matrix):
    """ calculate Cramers V statistic for categorial-categorial association.
        uses correction from Bergsma and Wicher, 
        Journal of the Korean Statistical Society 42 (2013): 323-328
    """
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min( (kcorr-1), (rcorr-1)))

# %%
cramers_v(data["Coarse-label"], data["POS"])
# Out:
# 0.38481970440097196

# %%
pd.crosstab(data["Coarse-label"], data["POS"])
# Out:
# POS             $(     $,     $.  -X-  ADJA  ADJD    ADV  APPO   APPR  \
# Coarse-label
# LOC              6      0      2    0   187     3      2     0     10
# MISC             9      6      2    0   790    49      5     0     21
# O             3076  10825  11603  553  9709  4391  10273    43  15739
# ORG             28      6      6    0   221    15      7     0     66
# PER              0      0      0    0    33    37      6     0     55
#
# POS           APPRART  ...  VAPP  VMFIN  VMINF  VMPP  VVFIN  VVIMP  VVINF  \
# Coarse-label           ...
# LOC                53  ...     0      0      0     0      3      2      5
# MISC                8  ...     0      0      0     0     16     17      4
# O                3494  ...   211   2054    107     2   8516     34   2925
# ORG                 7  ...     0      0      0     0     15      0      0
# PER                 1  ...     0      0      0     0      8     34      2
#
# POS           VVIZU  VVPP  XY
# Coarse-label
# LOC               0     1   0
# MISC              0     3   0
# O               301  3831   3
# ORG               0     2   0
# PER               0     5   0
#
# [5 rows x 55 columns]
